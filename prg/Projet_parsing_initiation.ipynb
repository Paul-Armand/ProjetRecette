# %%
import requests
from bs4 import BeautifulSoup

# %%
endpoint = "https://www.marmiton.org/"
response = requests.get(endpoint)
response.status_code
# Out:
# 200

# %%
html_content = response.text
html_content
# Out:
# '<!DOCTYPE html><html lang="fr"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><link rel="icon" type="image/png" sizes="64x64" href="https://www.marmiton.org/favicon.ico"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/><script lang="js">window.gdprAppliesGlobally=true;</script><script lang="js">!function(o,r){var d=o.Didomi||{},t=!1,a=!1,l=!1,s=!1,c="",u="multiple didomi-buttons didomi-popup-notice-buttons",n="buttons",p="style",m="form",i=o.console||{log:function(e){}},f=function(){},v={wall_active:!0};function g(){f=!1,r.getElementById("didomi-host").remove();var e=r.getElementById("old-didomi-host");e.setAttribute("id","didomi-host"),e.style.display="block",d.notice.show("informations")}function y(){return"<div class=\'didomi-popup-notice-logo-container\'><img class=\'didomi-popup-notice-logo\' alt=\'Logo\' src=\'"+d.getConfig().app.logoUrl+"\'></div>"}function b(e){e=Object.assign({id:"X",defaultClasses:"didomi-components-button didomi-button standard-button",class:"",content:"OK",disabled:!1},e);return e.class=e.defaultClasses+" "+e.class,e.disabled=e.disabled?"disabled":"","<button id=\'"+e.id+"\' class=\'"+e.class.trim()+"\' "+e.disabled+"><span>"+e.content+"</span></button>"}function h(){r.getElementById("old-didomi-host")||(t=r.getElementById("didomi-host"),(i=r.createElement("div")).setAttribute("id","didomi-host"),i.setAttribute("unifywall",!0),i.innerHTML=t.innerHTML,(e=i.querySelector(".didomi-popup-view"))&&(e.id="unify_wall_content",t.setAttribute("id","old-didomi-host"),t.style.display="none",r.body.insertBefore(i,r.getElementById("old-didomi-host")),r.body.classList.add("didomi-popup-open"),setTimeout(function(){r.body.classList.add("didomi-popup-open")},200),f=!1));var e=r.getElementById("unify_wall_content");if(e){var t={id:"unify-accept-finally",class:"didomi-button-highlight",content:v.btn_accept_finally},i={id:"unify-goto-subscribe",class:"didomi-button-highlight",content:v.btn_abo_text};return e.innerHTML=y()+"<div class=\'didomi-popup-notice-text-container\'><div class=\'didomi-popup-notice-text\'>"+v.paywall_text+"<div id=\'"+n+"\' class=\'"+u+"\'>"+b(t)+b(i)+"</div></div></div>",e.querySelector("#unify-accept-finally").addEventListener("click",function(){g(),d.setUserAgreeToAll(),r.body.classList.remove("didomi-popup-open")}),e.querySelector("#unify-goto-subscribe").addEventListener("click",function(){_()}),f=!1,1}}function _(){var o=r.getElementById("unify_wall_content");if(!o)return!1;var e=v.legal_text_full.split("</p>",1)[0]+"</p>",t={id:"unify-pay",class:"didomi-button-highlight",content:"Confirmer",disabled:0==c.trim().length};o.innerHTML=y()+"<div class=\'didomi-popup-notice-text-container\'><div class=\'didomi-popup-notice-text\'><div class=\'didomi-popup-title\'>"+v.prepayment_title+"</div><"+m+" action=\'/?payment\' method=\'post\' id=\'prepayment-form\'><div class=\'didomi-popup-form-row\'><div class=\'didomi-field-container didomi-field-container-2\'><input type=\'email\' name=\'email\' value=\'"+c+"\' placeholder=\'Adresse e-mail*\' aria-label=\'Adresse e-mail\' required /></div><div><small>* champ obligatoire</small></div></div><div class=\'didomi-popup-form-row\'><p><strong>"+v.legal_text_title+"</strong></p>"+e+"<p "+p+"=\'margin-top:-5px; text-align:center\'><svg id=\'unify-see-legal-screen\' xmlns=\'http://www.w3.org/2000/svg\' viewBox=\'0 0 452 452\' "+p+"=\'width:20px;margin:0 auto;cursor:pointer\'><path fill=\'"+d.getConfig().theme.color+"\' d=\'m226 355c-8 0-16-3-22-9l-194-194c-12-12-12-32 0-45 12-12 32-12 45 0l172 172 172-172c12-12 32-12 45 0 12 12 12 32 0 45l-194 194c-6 6-14 9-22 9z\'/></svg></p></div><div class=\'"+u+"\'>"+b({id:"unify-goback",content:"Retour"})+b(t)+"</div></"+m+"></div></div>",o.querySelector("#unify-goback").addEventListener("click",function(e){e.preventDefault(),o.querySelector("input[name=email]").remove(),h()}),o.querySelector("#unify-pa ...

# %%
soup = BeautifulSoup(html_content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html lang="fr"><head><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><link href="https://www.marmiton.org/favicon.ico" rel="icon" sizes="64x64" type="image/png"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/><script lang="js">window.gdprAppliesGlobally=true;</script><script lang="js">!function(o,r){var d=o.Didomi||{},t=!1,a=!1,l=!1,s=!1,c="",u="multiple didomi-buttons didomi-popup-notice-buttons",n="buttons",p="style",m="form",i=o.console||{log:function(e){}},f=function(){},v={wall_active:!0};function g(){f=!1,r.getElementById("didomi-host").remove();var e=r.getElementById("old-didomi-host");e.setAttribute("id","didomi-host"),e.style.display="block",d.notice.show("informations")}function y(){return"<div class='didomi-popup-notice-logo-container'><img class='didomi-popup-notice-logo' alt='Logo' src='"+d.getConfig().app.logoUrl+"'></div>"}function b(e){e=Object.assign({id:"X",defaultClasses:"didomi-components-button didomi-button standard-button",class:"",content:"OK",disabled:!1},e);return e.class=e.defaultClasses+" "+e.class,e.disabled=e.disabled?"disabled":"","<button id='"+e.id+"' class='"+e.class.trim()+"' "+e.disabled+"><span>"+e.content+"</span></button>"}function h(){r.getElementById("old-didomi-host")||(t=r.getElementById("didomi-host"),(i=r.createElement("div")).setAttribute("id","didomi-host"),i.setAttribute("unifywall",!0),i.innerHTML=t.innerHTML,(e=i.querySelector(".didomi-popup-view"))&&(e.id="unify_wall_content",t.setAttribute("id","old-didomi-host"),t.style.display="none",r.body.insertBefore(i,r.getElementById("old-didomi-host")),r.body.classList.add("didomi-popup-open"),setTimeout(function(){r.body.classList.add("didomi-popup-open")},200),f=!1));var e=r.getElementById("unify_wall_content");if(e){var t={id:"unify-accept-finally",class:"didomi-button-highlight",content:v.btn_accept_finally},i={id:"unify-goto-subscribe",class:"didomi-button-highlight",content:v.btn_abo_text};return e.innerHTML=y()+"<div class='didomi-popup-notice-text-container'><div class='didomi-popup-notice-text'>"+v.paywall_text+"<div id='"+n+"' class='"+u+"'>"+b(t)+b(i)+"</div></div></div>",e.querySelector("#unify-accept-finally").addEventListener("click",function(){g(),d.setUserAgreeToAll(),r.body.classList.remove("didomi-popup-open")}),e.querySelector("#unify-goto-subscribe").addEventListener("click",function(){_()}),f=!1,1}}function _(){var o=r.getElementById("unify_wall_content");if(!o)return!1;var e=v.legal_text_full.split("</p>",1)[0]+"</p>",t={id:"unify-pay",class:"didomi-button-highlight",content:"Confirmer",disabled:0==c.trim().length};o.innerHTML=y()+"<div class='didomi-popup-notice-text-container'><div class='didomi-popup-notice-text'><div class='didomi-popup-title'>"+v.prepayment_title+"</div><"+m+" action='/?payment' method='post' id='prepayment-form'><div class='didomi-popup-form-row'><div class='didomi-field-container didomi-field-container-2'><input type='email' name='email' value='"+c+"' placeholder='Adresse e-mail*' aria-label='Adresse e-mail' required /></div><div><small>* champ obligatoire</small></div></div><div class='didomi-popup-form-row'><p><strong>"+v.legal_text_title+"</strong></p>"+e+"<p "+p+"='margin-top:-5px; text-align:center'><svg id='unify-see-legal-screen' xmlns='http://www.w3.org/2000/svg' viewBox='0 0 452 452' "+p+"='width:20px;margin:0 auto;cursor:pointer'><path fill='"+d.getConfig().theme.color+"' d='m226 355c-8 0-16-3-22-9l-194-194c-12-12-12-32 0-45 12-12 32-12 45 0l172 172 172-172c12-12 32-12 45 0 12 12 12 32 0 45l-194 194c-6 6-14 9-22 9z'/></svg></p></div><div class='"+u+"'>"+b({id:"unify-goback",content:"Retour"})+b(t)+"</div></"+m+"></div></div>",o.querySelector("#unify-goback").addEventListener("click",function(e){e.preventDefault(),o.querySelector("input[name=email]").remove(),h()}),o.querySelector("#unify-pay").addEventListener("click",function(e){i(),e.preventDefault(),o.querySelector( ...
# </script><link href="https://pegasus.unifygroup.com" rel="dns-prefetch"/><title>Marmiton : 76560 recettes de cuisine commentées et notées pour toutes les cuisines !</title><meta content="76560 recettes de cuisine ! Recettes commentées et notées pour toutes les cuisines. Echangez vos recettes, donnez votre avis et progressez en cuisine." name="description"/><meta content="index,follow,max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/><meta content="fr" property="og:locale"/><meta content="Marmiton" property="og:site_name"/><link href="https://www.marmiton.org" rel="canonical"/><meta content="179380945463734" property="fb:app_id"/><meta content="Ouvrir marmiton.org" name="msapplication-tooltip"/><meta content="/" name="msapplication-starturl"/><meta content="#ff6f61" name="msapplication-navbutton-color"/><meta content="app-id=318796083" name="apple-itunes-app"/><script type="application/ld+json">{"@context":"http://schema.org","@type":"WebSite","name":"marmiton","url":"https://www.marmiton.org","image":"https://www.marmiton.org/reloaded/static/Front/Vendor/img/logo-marmiton-2.gif","publisher":{"@type":"Organization","name":"marmiton"},"sameAs":["https://fr.pinterest.com/marmiton/","https://www.facebook.com/marmiton","https://www.instagram.com/marmiton_org/","https://www.youtube.com/user/marmitonofficiel","https://www.twitch.tv/marmiton_officiel","https://www.tiktok.com/@marmiton_org"]}</script><link as="image" href="https://assets.afcdn.com/recipe/20220623/133014_w310h420c1.webp" imagesizes="310px" imagesrcset="https://assets.afcdn.com/recipe/20220623/133014_w310h420c1.webp 1x, https://assets.afcdn.com/recipe/20220623/133014_w620h840c1.webp 2x" rel="preload"/><meta content="21" name="next-head-count"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="https://assets.marmiton.org/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/webpack-5cbe3d6fc5a5a86e.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/framework-5d35e35cbb3a034d.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/main-8ce591f7301e20c1.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/pages/_app-6119236b6138b21c.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/763-d05cf60a5cc0c90c.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/601-20fbf9610f97aa69.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/295-7b36472d7d05757d.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/512-a3f117ca7bb8948e.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/543-152db7add4459b5e.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/926-a22b628d91d742c1.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/chunks/pages/index-f7e820f1f8679f05.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/hlpVzdZEnAhj6LPq7lW_I/_buildManifest.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/hlpVzdZEnAhj6LPq7lW_I/_ssgManifest.js"></script><script defer="" src="https://assets.marmiton.org/_next/static/hlpVzdZEnAhj6LPq7lW_I/_middlewareManifest.js"></script><style id="jss-server-side">.MuiPaper-root {
#   color: rgba(0, 0, 0, 0.87);
#   transition: box-shadow 300ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;
#   background-color: #fff;
# }
# .MuiPaper-rounded {
#   border-radius: 20px;
# }
# .MuiPaper-outlined {
#   border: 1px solid rgba(0, 0, 0, 0.12);
# }
# .MuiPaper-elevation0 {
#   box-shadow: none;
# }
# .MuiPaper-elevation1 {
#   box-shadow: 0px 2px 1px -1px rgba(0,0,0,0.2),0px 1px 1px 0px rgba(0,0,0,0.14),0px 1px 3px 0px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation2 {
#   box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2),0px 2px 2px 0px rgba(0,0,0,0.14),0px 1px 5px 0px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation3 {
#   box-shadow: 0px 3px 3px -2px rgba(0,0,0,0.2),0px 3px 4px 0px rgba(0,0,0,0.14),0px 1px 8px 0px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation4 {
#   box-shadow: 0px 2px 4px -1px rgba(0,0,0,0.2),0px 4px 5px 0px rgba(0,0,0,0.14),0px 1px 10px 0px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation5 {
#   box-shadow: 0px 3px 5px -1px rgba(0,0,0,0.2),0px 5px 8px 0px rgba(0,0,0,0.14),0px 1px 14px 0px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation6 {
#   box-shadow: 0px 3px 5px -1px rgba(0,0,0,0.2),0px 6px 10px 0px rgba(0,0,0,0.14),0px 1px 18px 0px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation7 {
#   box-shadow: 0px 4px 5px -2px rgba(0,0,0,0.2),0px 7px 10px 1px rgba(0,0,0,0.14),0px 2px 16px 1px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation8 {
#   box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation9 {
#   box-shadow: 0px 5px 6px -3px rgba(0,0,0,0.2),0px 9px 12px 1px rgba(0,0,0,0.14),0px 3px 16px 2px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation10 {
#   box-shadow: 0px 6px 6px -3px rgba(0,0,0,0.2),0px 10px 14px 1px rgba(0,0,0,0.14),0px 4px 18px 3px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation11 {
#   box-shadow: 0px 6px 7px -4px rgba(0,0,0,0.2),0px 11px 15px 1px rgba(0,0,0,0.14),0px 4px 20px 3px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation12 {
#   box-shadow: 0px 7px 8px -4px rgba(0,0,0,0.2),0px 12px 17px 2px rgba(0,0,0,0.14),0px 5px 22px 4px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation13 {
#   box-shadow: 0px 7px 8px -4px rgba(0,0,0,0.2),0px 13px 19px 2px rgba(0,0,0,0.14),0px 5px 24px 4px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation14 {
#   box-shadow: 0px 7px 9px -4px rgba(0,0,0,0.2),0px 14px 21px 2px rgba(0,0,0,0.14),0px 5px 26px 4px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation15 {
#   box-shadow: 0px 8px 9px -5px rgba(0,0,0,0.2),0px 15px 22px 2px rgba(0,0,0,0.14),0px 6px 28px 5px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation16 {
#   box-shadow: 0px 8px 10px -5px rgba(0,0,0,0.2),0px 16px 24px 2px rgba(0,0,0,0.14),0px 6px 30px 5px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation17 {
#   box-shadow: 0px 8px 11px -5px rgba(0,0,0,0.2),0px 17px 26px 2px rgba(0,0,0,0.14),0px 6px 32px 5px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation18 {
#   box-shadow: 0px 9px 11px -5px rgba(0,0,0,0.2),0px 18px 28px 2px rgba(0,0,0,0.14),0px 7px 34px 6px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation19 {
#   box-shadow: 0px 9px 12px -6px rgba(0,0,0,0.2),0px 19px 29px 2px rgba(0,0,0,0.14),0px 7px 36px 6px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation20 {
#   box-shadow: 0px 10px 13px -6px rgba(0,0,0,0.2),0px 20px 31px 3px rgba(0,0,0,0.14),0px 8px 38px 7px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation21 {
#   box-shadow: 0px 10px 13px -6px rgba(0,0,0,0.2),0px 21px 33px 3px rgba(0,0,0,0.14),0px 8px 40px 7px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation22 {
#   box-shadow: 0px 10px 14px -6px rgba(0,0,0,0.2),0px 22px 35px 3px rgba(0,0,0,0.14),0px 8px 42px 7px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation23 {
#   box-shadow: 0px 11px 14px -7px rgba(0,0,0,0.2),0px 23px 36px 3px rgba(0,0,0,0.14),0px 9px 44px 8px rgba(0,0,0,0.12);
# }
# .MuiPaper-elevation24 {
#   box-shadow: 0px 11px 15px -7px rgba(0,0,0,0.2),0px 24px 38px 3px rgba(0,0,0,0.14),0px 9px 46px 8px rgba(0,0,0,0.12);
# }
# .MuiButtonBase-root {
#   color: inherit;
#   border: 0;
#   cursor: pointer;
#   margin: 0;
#   display: inline-flex;
#   outline: 0;
#   padding: 0;
#   position: relative;
#   align-items: center;
#   user-select: none;
#   border-radius: 0;
#   vertical-align: middle;
#   -moz-appearance: none;
#   justify-content: center;
#   text-decoration: none;
#   background-color: transparent;
#   -webkit-appearance: none;
#   -webkit-tap-highlight-color: transparent;
# }
# .MuiButtonBase-root::-moz-focus-inner {
#   border-style: none;
# }
# .MuiButtonBase-root.Mui-disabled {
#   cursor: default;
#   pointer-events: none;
# }
# @media print {
#   .MuiButtonBase-root {
#     color-adjust: exact;
#   }
# }
#   .MuiTypography-root {
#     margin: 0;
#   }
#   .MuiTypography-body2 {
#     font-size: 12px;
#     font-family: Open Sans;
#     font-weight: 400;
#     line-height: 1.43;
#     letter-spacing: 0.01071em;
#   }
#   .MuiTypography-body1 {
#     font-size: 16px;
#     font-family: Open Sans;
#     font-weight: 400;
#     line-height: 1.5;
#     letter-spacing: 0.00938em;
#   }
#   .MuiTypography-caption {
#     font-size: 16px;
#     font-family: Filson Soft;
#     font-weight: 400;
#     line-height: 1.66;
#     letter-spacing: 0.03333em;
#   }
#   .MuiTypography-button {
#     font-size: 16px;
#     font-family: "Roboto", "Helvetica", "Arial", sans-serif;
#     font-weight: 500;
#     line-height: 1.75;
#     letter-spacing: 0.02857em;
#     text-transform: uppercase;
#   }
#   .MuiTypography-h1 {
#     font-size: 38px;
#     font-family: Filson Soft;
#     font-weight: bold;
#     line-height: 1.167;
#     letter-spacing: -0.01562em;
#   }
#   .MuiTypography-h2 {
#     font-size: 30px;
#     font-family: Filson Soft;
#     font-weight: bold;
#     line-height: 1.2;
#     letter-spacing: -0.00833em;
#   }
#   .MuiTypography-h3 {
#     font-size: 22px;
#     font-family: Filson Soft;
#     font-weight: 500;
#     line-height: 1.36;
#     letter-spacing: 0em;
#   }
#   .MuiTypography-h4 {
#     font-size: 20px;
#     font-family: Filson Soft;
#     font-weight: bold;
#     line-height: 1.235;
#     letter-spacing: 0.00735em;
#   }
#   .MuiTypography-h5 {
#     font-size: 16px;
#     font-family: Open Sans;
#     font-weight: 600;
#     line-height: 1.334;
#     letter-spacing: 0em;
#   }
#   .MuiTypography-h6 {
#     font-size: 14px;
#     font-family: Open Sans;
#     font-weight: 600;
#     line-height: 1.6;
#     letter-spacing: 0.0075em;
#   }
#   .MuiTypography-subtitle1 {
#     font-size: 19px;
#     font-family: Open Sans;
#     font-weight: bold;
#     line-height: 1.75;
#     letter-spacing: 0.00938em;
#   }
#   .MuiTypography-subtitle2 {
#     font-size: 19px;
#     font-family: Open Sans;
#     font-weight: normal;
#     line-height: 1.57;
#     letter-spacing: 0.00714em;
#   }
#   .MuiTypography-overline {
#     font-size: 0.75rem;
#     font-family: "Roboto", "Helvetica", "Arial", sans-serif;
#     font-weight: 400;
#     line-height: 2.66;
#     letter-spacing: 0.08333em;
#     text-transform: uppercase;
#   }
#   .MuiTypography-srOnly {
#     width: 1px;
#     height: 1px;
#     overflow: hidden;
#     position: absolute;
#   }
#   .MuiTypography-alignLeft {
#     text-align: left;
#   }
#   .MuiTypography-alignCenter {
#     text-align: center;
#   }
#   .MuiTypography-alignRight {
#     text-align: right;
#   }
#   .MuiTypography-alignJustify {
#     text-align: justify;
#   }
#   .MuiTypography-noWrap {
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
#   }
#   .MuiTypography-gutterBottom {
#     margin-bottom: 0.35em;
#   }
#   .MuiTypography-paragraph {
#     margin-bottom: 16px;
#   }
#   .MuiTypography-colorInherit {
#     color: inherit;
#   }
#   .MuiTypography-colorPrimary {
#     color: #998b89;
#   }
#   .MuiTypography-colorSecondary {
#     color: #ff6f61;
#   }
#   .MuiTypography-colorTextPrimary {
#     color: rgba(0, 0, 0, 0.87);
#   }
#   .MuiTypography-colorTextSecondary {
#     color: rgba(0, 0, 0, 0.54);
#   }
#   .MuiTypography-colorError {
#     color: #f44336;
#   }
#   .MuiTypography-displayInline {
#     display: inline;
#   }
#   .MuiTypography-displayBlock {
#     display: block;
#   }
#   .MuiButton-root {
#     color: rgba(0, 0, 0, 0.87);
#     padding: 13px 40px;
#     font-size: 16px;
#     min-width: 64px;
#     box-sizing: border-box;
#     transition: background-color 250ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,box-shadow 250ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,border 250ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;
#     font-family: "Roboto", "Helvetica", "Arial", sans-serif;
#     font-weight: 500;
#     line-height: 1.75;
#     white-space: nowrap;
#     border-radius: 33px;
#     letter-spacing: 0.02857em;
#     text-transform: none;
#   }
#   .MuiButton-root:hover {
#     text-decoration: none;
#     background-color: rgba(0, 0, 0, 0.04);
#   }
#   .MuiButton-root.Mui-disabled {
#     color: rgba(0, 0, 0, 0.26);
#   }
# @media (hover: none) {
#   .MuiButton-root:hover {
#     background-color: transparent;
#   }
# }
#   .MuiButton-root:hover.Mui-disabled {
#     background-color: transparent;
#   }
#   .MuiButton-label {
#     width: 100%;
#     display: inherit;
#     align-items: inherit;
#     justify-content: inherit;
#   }
#   .MuiButton-text {
#     padding: 13px 40px;
#     box-shadow: 1px 2px 9px 0 rgba(0, 0, 0, 0.13);
#   }
#   .MuiButton-textPrimary {
#     color: #ff6f61;
#   }
#   .MuiButton-textPrimary:hover {
#     background-color: rgba(153, 139, 137, 0.04);
#   }
# @media (hover: none) {
#   .MuiButton-textPrimary:hover {
#     background-color: transparent;
#   }
# }
#   .MuiButton-textSecondary {
#     color: #ff6f61;
#     padding: 13px 40px;
#     box-shadow: none;
#   }
#   .MuiButton-textSecondary:hover {
#     background-color: rgba(255, 111, 97, 0.04);
#   }
# @media (hover: none) {
#   .MuiButton-textSecondary:hover {
#     background-color: transparent;
#   }
# }
#   .MuiButton-outlined {
#     border: 1px solid rgba(0, 0, 0, 0.23);
#     padding: 12px 40px;
#   }
#   .MuiButton-outlined.Mui-disabled {
#     border: 1px solid rgba(0, 0, 0, 0.12);
#   }
#   .MuiButton-outlinedPrimary {
#     color: #ff6f61;
#     border: 1px solid #ff6f61;
#     background-color: #fff;
#   }
#   .MuiButton-outlinedPrimary:hover {
#     color: #fff;
#     border: 1px solid #ff6f61;
#     background-color: #ff6f61;
#   }
# @media (hover: none) {
#   .MuiButton-outlinedPrimary:hover {
#     background-color: transparent;
#   }
# }
#   .MuiButton-outlinedSecondary {
#     color: #ff6f61;
#     border: 1px solid rgba(255, 111, 97, 0.5);
#   }
#   .MuiButton-outlinedSecondary:hover {
#     border: 1px solid #ff6f61;
#     background-color: rgba(255, 111, 97, 0.04);
#   }
#   .MuiButton-outlinedSecondary.Mui-disabled {
#     border: 1px solid rgba(0, 0, 0, 0.26);
#   }
# @media (hover: none) {
#   .MuiButton-outlinedSecondary:hover {
#     background-color: transparent;
#   }
# }
#   .MuiButton-contained {
#     color: rgba(0, 0, 0, 0.87);
#     box-shadow: none;
#     background-color: #e0e0e0;
#   }
#   .MuiButton-contained:hover {
#     box-shadow: none;
#     background-color: #d5d5d5;
#   }
#   .MuiButton-contained.Mui-focusVisible {
#     box-shadow: 0px 3px 5px -1px rgba(0,0,0,0.2),0px 6px 10px 0px rgba(0,0,0,0.14),0px 1px 18px 0px rgba(0,0,0,0.12);
#   }
#   .MuiButton-contained:active {
#     box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#   }
#   .MuiButton-contained.Mui-disabled {
#     color: rgba(0, 0, 0, 0.26);
#     box-shadow: none;
#     background-color: rgba(0, 0, 0, 0.12);
#   }
# @media (hover: none) {
#   .MuiButton-contained:hover {
#     box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2),0px 2px 2px 0px rgba(0,0,0,0.14),0px 1px 5px 0px rgba(0,0,0,0.12);
#     background-color: #e0e0e0;
#   }
# }
#   .MuiButton-contained:hover.Mui-disabled {
#     background-color: rgba(0, 0, 0, 0.12);
#   }
#   .MuiButton-containedPrimary {
#     color: #fff;
#     background-color: #ff6f61;
#   }
#   .MuiButton-containedPrimary:hover {
#     background-color: #FF9B90;
#   }
# @media (hover: none) {
#   .MuiButton-containedPrimary:hover {
#     background-color: #FF9B90;
#   }
# }
#   .MuiButton-containedSecondary {
#     color: #000;
#     background-color: #ff6f61;
#   }
#   .MuiButton-containedSecondary:hover {
#     background-color: #db212f;
#   }
# @media (hover: none) {
#   .MuiButton-containedSecondary:hover {
#     background-color: #ff6f61;
#   }
# }
#   .MuiButton-disableElevation {
#     box-shadow: none;
#   }
#   .MuiButton-disableElevation:hover {
#     box-shadow: none;
#   }
#   .MuiButton-disableElevation.Mui-focusVisible {
#     box-shadow: none;
#   }
#   .MuiButton-disableElevation:active {
#     box-shadow: none;
#   }
#   .MuiButton-disableElevation.Mui-disabled {
#     box-shadow: none;
#   }
#   .MuiButton-colorInherit {
#     color: inherit;
#     border-color: currentColor;
#   }
#   .MuiButton-textSizeSmall {
#     padding: 9px 16px;
#     font-size: 0.8125rem;
#   }
#   .MuiButton-textSizeLarge {
#     padding: 8px 11px;
#     font-size: 0.9375rem;
#   }
#   .MuiButton-outlinedSizeSmall {
#     padding: 8px 16px;
#     font-size: 0.8125rem;
#   }
#   .MuiButton-outlinedSizeLarge {
#     padding: 7px 21px;
#     font-size: 0.9375rem;
#   }
#   .MuiButton-containedSizeSmall {
#     padding: 9px 16px;
#     font-size: 0.8125rem;
#   }
#   .MuiButton-containedSizeLarge {
#     padding: 8px 22px;
#     font-size: 0.9375rem;
#   }
#   .MuiButton-sizeSmall {
#     font-size: 13px;
#   }
#   .MuiButton-sizeLarge {
#     padding: 13px 90px;
#     font-size: 16px;
#     border-radius: 33px;
#   }
#   .MuiButton-fullWidth {
#     width: 100%;
#   }
#   .MuiButton-startIcon {
#     display: inherit;
#     margin-left: -4px;
#     margin-right: 8px;
#   }
#   .MuiButton-startIcon.MuiButton-iconSizeSmall {
#     margin-left: -2px;
#   }
#   .MuiButton-startIcon svg {
#     fill: currentColor;
#     width: auto;
#     height: 20px;
#   }
#   .MuiButton-endIcon {
#     display: inherit;
#     margin-left: 8px;
#     margin-right: -4px;
#   }
#   .MuiButton-endIcon.MuiButton-iconSizeSmall {
#     margin-right: -2px;
#   }
#   .MuiButton-iconSizeSmall > *:first-child {
#     font-size: 18px;
#   }
#   .MuiButton-iconSizeMedium > *:first-child {
#     font-size: 20px;
#   }
#   .MuiButton-iconSizeLarge > *:first-child {
#     font-size: 22px;
#   }
#   .MuiCard-root {
#     overflow: hidden;
#   }</style><style data-styled="" data-styled-version="5.3.1">.eoGQen{width:100%;height:var(--pegasus-ad-title-height,20px);padding:10px;color:#aaa5a5;font-size:15px;text-align:center;}/*!sc*/
# data-styled.g4[id="SHRD__sc-1tz01b7-0"]{content:"eoGQen,"}/*!sc*/
# .lkfzdY{--pegasus-cls-height:100px;--pegasus-ad-title-height:40px;position:relative;height:calc(var(--pegasus-cls-height) + var(--pegasus-ad-title-height));overflow:hidden;background-color:rgba(255,111,97,0.1);background-image:url(https://assets.marmiton.org/adLogo.svg);background-repeat:no-repeat;background-position:50%;}/*!sc*/
# @media (min-width:1024px){.lkfzdY{--pegasus-cls-height:250px;}}/*!sc*/
# data-styled.g5[id="SHRD__sc-oypy6n-0"]{content:"lkfzdY,"}/*!sc*/
# .gOjqhO{position:relative;margin:auto;}/*!sc*/
# @media (min-width:1024px){.gOjqhO{width:1000px;}}/*!sc*/
# data-styled.g6[id="SHRD__sc-juz8gd-0"]{content:"gOjqhO,"}/*!sc*/
# .hRMkyM{--pegasus-cls-height:100px;}/*!sc*/
# @media (min-width:1024px){.hRMkyM{--pegasus-cls-height:250px;}}/*!sc*/
# data-styled.g11[id="SHRD__sc-1ny3xf3-0"]{content:"hRMkyM,"}/*!sc*/
# .ibKgdh{text-align:left;}/*!sc*/
# @media (min-width:320px){.ibKgdh{font-family:Open Sans !important;font-size:14px !important;font-weight:600 !important;color:#3f3735 !important;}}/*!sc*/
# .hZpypO{text-align:left;}/*!sc*/
# @media (min-width:320px){.hZpypO{font-family:Open Sans !important;font-size:18px !important;font-weight:600 !important;line-height:24px !important;}}/*!sc*/
# .eTGQoW{text-align:left;}/*!sc*/
# @media (min-width:320px){.eTGQoW{font-family:Open Sans !important;font-size:12px !important;font-weight:400 !important;}}/*!sc*/
# .boNNvB{text-align:left;}/*!sc*/
# @media (min-width:320px){.boNNvB{font-family:Open Sans !important;font-size:16px !important;font-weight:400 !important;color:#998b89 !important;}}/*!sc*/
# .dtAavD{text-align:left;}/*!sc*/
# @media (min-width:320px){.dtAavD{font-family:Filson Soft !important;font-size:22px !important;font-weight:500 !important;color:#3f3735 !important;}}/*!sc*/
# .WctGr{text-align:left;}/*!sc*/
# @media (min-width:320px){.WctGr{font-family:Open Sans !important;font-size:16px !important;font-weight:600 !important;color:#3f3735 !important;}}/*!sc*/
# .gkDzpF{text-align:inherit;}/*!sc*/
# @media (min-width:320px){.gkDzpF{font-family:Filson Soft !important;font-size:24px !important;font-weight:700 !important;color:#3f3735 !important;}}/*!sc*/
# .kJAgeX{text-align:left;}/*!sc*/
# @media (min-width:320px){.kJAgeX{font-family:Open Sans !important;font-size:14px !important;color:#fff !important;font-weight:700 !important;line-height:22px !important;}}/*!sc*/
# .fXKPXw{text-align:left;}/*!sc*/
# @media (min-width:320px){.fXKPXw{font-family:Open Sans !important;font-size:12px !important;color:#fff !important;}}/*!sc*/
# .bWAtjm{text-align:inherit;}/*!sc*/
# @media (min-width:320px){.bWAtjm{font-family:Filson Soft !important;font-size:20px !important;font-weight:700 !important;color:#ff6f61 !important;}}/*!sc*/
# @media (min-width:768px){.bWAtjm{font-size:24px !important;line-height:25px !important;}}/*!sc*/
# .jXovwz{text-align:inherit;}/*!sc*/
# @media (min-width:320px){.jXovwz{font-family:Open Sans !important;font-size:16px !important;font-weight:400 !important;line-height:22px !important;color:#3f3735 !important;}}/*!sc*/
# @media (min-width:768px){.jXovwz{font-size:18px !important;font-weight:600 !important;line-height:25px !important;}}/*!sc*/
# .gEPlEt{text-align:left;}/*!sc*/
# @media (min-width:320px){.gEPlEt{font-family:Open Sans !important;font-size:18px !important;font-weight:700 !important;line-height:25px !important;color:#3f3735 !important;}}/*!sc*/
# .ithnUm{text-align:left;}/*!sc*/
# @media (min-width:320px){.ithnUm{font-family:Open Sans !important;font-size:16px !important;font-weight:600 !important;line-height:25px !important;color:#3f3735 !important;}}/*!sc*/
# .buQPRu{text-align:left;}/*!sc*/
# @media (min-width:320px){.buQPRu{font-family:Open Sans !important;font-size:16px !important;font-weight:700 !important;color:#3f3735 !important;}}/*!sc*/
# .eekbgT{text-align:center;}/*!sc*/
# @media (min-width:320px){.eekbgT{font-family:Open Sans !important;font-weight:700 !important;font-size:13px !important;color:#3f3735 !important;}}/*!sc*/
# .VwjCb{text-align:left;}/*!sc*/
# @media (min-width:320px){.VwjCb{font-family:Open Sans !important;font-size:14px !important;font-weight:400 !important;color:#3f3735 !important;}}/*!sc*/
# .sgkqV{text-align:left;}/*!sc*/
# @media (min-width:320px){.sgkqV{font-family:Open Sans !important;font-size:18px !important;font-weight:600 !important;color:#3f3735 !important;}}/*!sc*/
# .gsCwoY{text-align:left;}/*!sc*/
# @media (min-width:320px){.gsCwoY{font-family:Filson Soft !important;font-size:18px !important;font-weight:700 !important;color:#3f3735 !important;}}/*!sc*/
# .jaAjPW{text-align:left;}/*!sc*/
# @media (min-width:320px){.jaAjPW{font-family:Filson Soft !important;font-size:18px !important;font-weight:500 !important;color:#705669 !important;}}/*!sc*/
# .dQIjRV{text-align:left;}/*!sc*/
# @media (min-width:320px){.dQIjRV{font-family:Open Sans !important;font-size:12px !important;font-weight:400 !important;color:#705669 !important;}}/*!sc*/
# .iLWBNo{text-align:left;}/*!sc*/
# @media (min-width:320px){.iLWBNo{font-family:Filson Soft !important;font-size:22px !important;font-weight:500 !important;color:#3f3735 !important;}}/*!sc*/
# @media (min-width:1024px){.iLWBNo{font-size:24px !important;font-weight:700 !important;}}/*!sc*/
# .cecXQG{text-align:center;}/*!sc*/
# @media (min-width:320px){.cecXQG{font-family:Open Sans !important;font-size:12px !important;font-weight:400 !important;}}/*!sc*/
# .grYblt{text-align:center;}/*!sc*/
# @media (min-width:320px){.grYblt{font-family:Open Sans !important;font-size:16px !important;font-weight:700 !important;}}/*!sc*/
# .gzkOWL{text-align:left;}/*!sc*/
# @media (min-width:320px){.gzkOWL{font-family:Filson Soft !important;font-size:24px !important;font-weight:700 !important;color:#3f3735 !important;}}/*!sc*/
# .ibdVYR{text-align:left;}/*!sc*/
# @media (min-width:320px){.ibdVYR{font-family:Open Sans !important;font-size:16px !important;font-weight:400 !important;color:#3f3735 !important;}}/*!sc*/
# .jHqZL{text-align:left;}/*!sc*/
# @media (min-width:320px){.jHqZL{font-family:Filson Soft !important;font-size:22px !important;font-weight:500 !important;color:#ff6f61 !important;}}/*!sc*/
# .FRJxJ{text-align:left;}/*!sc*/
# @media (min-width:320px){.FRJxJ{font-family:Open Sans !important;font-size:16px !important;font-weight:400 !important;line-height:22px !important;color:#3f3735 !important;}}/*!sc*/
# @media (min-width:768px){.FRJxJ{font-size:18px !important;font-weight:600 !important;line-height:25px !important;}}/*!sc*/
# .bjtfRl{text-align:left;}/*!sc*/
# @media (min-width:320px){.bjtfRl{font-family:Filson Soft !important;font-size:18px !important;font-weight:500 !important;line-height:20px !important;}}/*!sc*/
# .fvHBlY{text-align:inherit;}/*!sc*/
# @media (min-width:320px){.fvHBlY{font-family:Filson Soft !important;font-size:22px !important;font-weight:400 !important;color:#ff6f61 !important;}}/*!sc*/
# .lktsJl{text-align:left;}/*!sc*/
# @media (min-width:320px){.lktsJl{font-family:Open Sans !important;font-size:14px !important;font-weight:600 !important;color:#3f3735 !important;line-height:19px !important;}}/*!sc*/
# @media (min-width:1024px){.lktsJl{font-size:18px !important;line-height:25px !important;}}/*!sc*/
# data-styled.g12[id="SHRD__sc-10plygc-0"]{content:"ibKgdh,hZpypO,eTGQoW,boNNvB,dtAavD,WctGr,gkDzpF,kJAgeX,fXKPXw,bWAtjm,jXovwz,gEPlEt,ithnUm,buQPRu,eekbgT,VwjCb,sgkqV,gsCwoY,jaAjPW,dQIjRV,iLWBNo,cecXQG,grYblt,gzkOWL,ibdVYR,jHqZL,FRJxJ,bjtfRl,fvHBlY,lktsJl,"}/*!sc*/
# @-webkit-keyframes pegasusspinner{0%{-webkit-transform:translate(-50%,-50%) rotate(0);-ms-transform:translate(-50%,-50%) rotate(0);transform:translate(-50%,-50%) rotate(0);}100%{-webkit-transform:translate(-50%,-50%) rotate(360deg);-ms-transform:translate(-50%,-50%) rotate(360deg);transform:translate(-50%,-50%) rotate(360deg);}}/*!sc*/
# @keyframes pegasusspinner{0%{-webkit-transform:translate(-50%,-50%) rotate(0);-ms-transform:translate(-50%,-50%) rotate(0);transform:translate(-50%,-50%) rotate(0);}100%{-webkit-transform:translate(-50%,-50%) rotate(360deg);-ms-transform:translate(-50%,-50%) rotate(360deg);transform:translate(-50%,-50%) rotate(360deg);}}/*!sc*/
# [data-ad-cls]{text-align:center;position:relative;}/*!sc*/
# [data-ad-cls]:before{content:'';margin:0 auto;display:block;width:100%;}/*!sc*/
# [data-ad-cls]:before{width:300px;height:250px;height:var(--pegasus-cls-height,250px);}/*!sc*/
# [data-ad-cls][data-ad='banner_atf']:before,[data-ad-cls][data-ad='banner_btf']:before,[data-ad-cls][data-ad='banner_mtf']:before{width:320px;height:50px;height:var(--pegasus-cls-height,50px);}/*!sc*/
# @media screen and (min-width:748px){[data-ad-cls]:before{height:600px;height:var(--pegasus-cls-height,600px);}[data-ad-cls][data-ad='dyninfeed']:before{height:250px;height:var(--pegasus-cls-height,250px);}[data-ad-cls][data-ad='banner_atf']:before,[data-ad-cls][data-ad='banner_btf']:before,[data-ad-cls][data-ad='banner_mtf']:before{width:728px;height:90px;height:var(--pegasus-cls-height,90px);}}/*!sc*/
# [data-ad-cls]:not([data-ad='native_shopping']):not([data-ad='banner_mtf']):not([data-ad='banner_btf']):not([data-ad='dyninfeed']):not([data-ad='300_atf']):not([data-ad='300_diapodynamic']):not([data-ad='300_mtf']):before{background:var(--pegasus-cls-background-color,#f5f5f5);border:1px solid var(--pegasus-cls-border-color,#ededed);}/*!sc*/
# [data-ad-cls]:not([data-ad='native_shopping']):not([data-ad='banner_mtf']):not([data-ad='banner_btf']):not([data-ad='dyninfeed']):not([data-ad='300_atf']):not([data-ad='300_diapodynamic']):not([data-ad='300_mtf']):after{content:'';border:4px solid var(--pegasus-cls-spinner-color,#ededed);border-radius:50%;border-top-color:transparent;margin:0 auto;position:absolute;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);top:50%;left:50%;width:25px;height:25px;-webkit-animation:pegasusspinner 0.8s linear infinite;animation:pegasusspinner 0.8s linear infinite;}/*!sc*/
# data-styled.g13[id="sc-global-gOeiVl1"]{content:"sc-global-gOeiVl1,"}/*!sc*/
# .dLDbdB{cursor:pointer;}/*!sc*/
# data-styled.g19[id="SHRD__sc-z48gov-0"]{content:"dLDbdB,"}/*!sc*/
# .jvysFr{display:block;width:100%;height:auto;aspect-ratio:310 / 420;}/*!sc*/
# .gdKOkr{display:block;width:100%;height:auto;aspect-ratio:120 / 120;}/*!sc*/
# .iKTVez{display:block;width:100%;height:auto;aspect-ratio:225 / 225;}/*!sc*/
# .gfzRng{display:block;width:100%;height:auto;aspect-ratio:482 / 287;}/*!sc*/
# .ddUfHv{display:block;width:100%;height:auto;aspect-ratio:200 / 200;}/*!sc*/
# .BaPtT{display:block;width:100%;height:auto;aspect-ratio:300 / 300;}/*!sc*/
# .eCZkjf{display:block;width:100%;height:auto;aspect-ratio:40 / 40;}/*!sc*/
# .iIAGly{display:block;width:100%;height:auto;aspect-ratio:950 / 375;}/*!sc*/
# .izYnrv{display:block;width:100%;height:auto;aspect-ratio:230 / 230;}/*!sc*/
# .ckZBTR{display:block;width:100%;height:auto;aspect-ratio:131 / 162;}/*!sc*/
# data-styled.g44[id="SHRD__sc-dy77ha-0"]{content:"jvysFr,gdKOkr,iKTVez,gfzRng,ddUfHv,BaPtT,eCZkjf,iIAGly,izYnrv,ckZBTR,"}/*!sc*/
# .jxQcRj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g46[id="SHRD__sc-1q3upxa-1"]{content:"jxQcRj,"}/*!sc*/
# .egbhkM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g47[id="SHRD__sc-1q3upxa-2"]{content:"egbhkM,"}/*!sc*/
# .gwcoTh{width:14px;height:14px;margin-right:2.5px;fill:#ff6f61;fill:#998b89;}/*!sc*/
# data-styled.g48[id="SHRD__sc-sr6s0j-0"]{content:"gwcoTh,"}/*!sc*/
# .gBAIBK{width:14px;height:14px;margin-right:2.5px;fill:currentColor;}/*!sc*/
# .cuxuXS{width:14px;height:14px;margin-right:2.5px;fill:#ff6f61;}/*!sc*/
# data-styled.g49[id="SHRD__sc-sr6s0j-1"]{content:"gBAIBK,cuxuXS,"}/*!sc*/
# .iuuKlN{width:14px;height:14px;margin-right:2.5px;fill:currentColor;}/*!sc*/
# .eHPLKd{width:14px;height:14px;margin-right:2.5px;fill:#ff6f61;}/*!sc*/
# data-styled.g50[id="SHRD__sc-sr6s0j-2"]{content:"iuuKlN,eHPLKd,"}/*!sc*/
# .dsaFkJ .swiper-button-prev,.dsaFkJ .swiper-button-next{top:45%;width:40px;height:40px;color:#000;font-weight:700;background:#fff;border-radius:50%;outline:0;box-shadow:-1px 5px 8px 0 rgba(0,0,0,0.12);-webkit-transition:background-color 0.2s ease,color 0.2s ease;transition:background-color 0.2s ease,color 0.2s ease;}/*!sc*/
# .dsaFkJ .swiper-button-prev::after,.dsaFkJ .swiper-button-next::after{font-size:16px;}/*!sc*/
# .dsaFkJ .swiper-scrollbar-drag{background:#F9F9F9;}/*!sc*/
# .dsaFkJ .swiper-button-prev.swiper-button-disabled,.dsaFkJ .swiper-button-next.swiper-button-disabled{cursor:auto;opacity:0;pointer-events:none;}/*!sc*/
# .dsaFkJ .swiper-slide{margin:0 10px;}/*!sc*/
# data-styled.g77[id="SHRD__sc-19x6cmr-0"]{content:"dsaFkJ,"}/*!sc*/
# html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,sub,sup,strike,strong,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;font:inherit;font-size:100%;line-height:normal;vertical-align:baseline;border:0;}/*!sc*/
# body,html{-webkit-font-smoothing:antialiased;}/*!sc*/
# a{color:inherit;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;}/*!sc*/
# button{-webkit-tap-highlight-color:transparent;background:transparent;border:0;border-radius:0;cursor:pointer;}/*!sc*/
# input:focus,textarea:focus,button:focus,select:focus{outline:none;}/*!sc*/
# article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}/*!sc*/
# ol,ul{list-style:none;}/*!sc*/
# blockquote,q{quotes:none;}/*!sc*/
# blockquote::before,blockquote::after,q::before,q::after{content:'';content:none;}/*!sc*/
# table{border-collapse:collapse;border-spacing:0;}/*!sc*/
# *{box-sizing:border-box;}/*!sc*/
# html{height:100vh;}/*!sc*/
# body,#__next{min-height:100%;}/*!sc*/
# input{border:none;outline:none;}/*!sc*/
# data-styled.g78[id="sc-global-fQCEVj1"]{content:"sc-global-fQCEVj1,"}/*!sc*/
# .fKSEvo{width:36px;min-width:36px;height:36px;padding:5px;background-color:#fff;border-radius:50%;}/*!sc*/
# .fKSEvo:hover{background-color:#fff;}/*!sc*/
# .fKSEvo svg{width:20px;height:20px;fill:#ff6f61;}/*!sc*/
# data-styled.g119[id="RCP__sc-1eraxc1-0"]{content:"fKSEvo,"}/*!sc*/
# .jGXfCy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-bottom:5px;text-align:justify;}/*!sc*/
# .hTLgFP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-bottom:0;text-align:justify;}/*!sc*/
# data-styled.g123[id="RCP__sc-10tiafs-1"]{content:"jGXfCy,hTLgFP,"}/*!sc*/
# .jkfaRL{color:currentColor;}/*!sc*/
# .iFABQv{color:#998b89;}/*!sc*/
# data-styled.g124[id="RCP__sc-10tiafs-2"]{content:"jkfaRL,iFABQv,"}/*!sc*/
# .bGXwvU{color:currentColor;text-align:justify;}/*!sc*/
# .bPdimU{color:#998b89;text-align:justify;}/*!sc*/
# data-styled.g125[id="RCP__sc-10tiafs-3"]{content:"bGXwvU,bPdimU,"}/*!sc*/
# .bPpNIH{z-index:10;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;gap:0;color:currentColor;cursor:pointer;}/*!sc*/
# data-styled.g126[id="RCP__sc-yl30o1-0"]{content:"bPpNIH,"}/*!sc*/
# .bUJOoh{position:relative;-webkit-flex:1;-ms-flex:1;flex:1;margin-bottom:10px;overflow:hidden;border-radius:15px;}/*!sc*/
# .bUJOoh img{height:100%;object-fit:cover;}/*!sc*/
# @media (min-width:768px){.bUJOoh{margin-bottom:5px;}}/*!sc*/
# data-styled.g127[id="RCP__sc-yl30o1-1"]{content:"bUJOoh,"}/*!sc*/
# .govcOP{position:absolute;top:10px;right:10px;width:35px;height:35px;padding:10px;border-radius:50%;}/*!sc*/
# .govcOP > button{right:19px;bottom:11px;box-shadow:none;}/*!sc*/
# data-styled.g128[id="RCP__sc-yl30o1-2"]{content:"govcOP,"}/*!sc*/
# .AjkxX{position:absolute;bottom:10px;left:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:1px 5px;background-color:#fff;border-top-left-radius:20px;border-top-right-radius:20px;border-bottom-right-radius:20px;border-bottom-left-radius:20px;}/*!sc*/
# data-styled.g129[id="RCP__sc-yl30o1-3"]{content:"AjkxX,"}/*!sc*/
# .hTInD{width:13px;height:13px;margin-right:5px;}/*!sc*/
# data-styled.g130[id="RCP__sc-yl30o1-4"]{content:"hTInD,"}/*!sc*/
# .efumWh{display:-moz-box;display:-webkit-box;margin-bottom:5px;overflow:hidden;text-overflow:ellipsis;-webkit-line-clamp:2;-moz-box-orient:vertical;-webkit-box-orient:vertical;}/*!sc*/
# data-styled.g132[id="RCP__sc-yl30o1-6"]{content:"efumWh,"}/*!sc*/
# .fjWSiv{-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g135[id="RCP__sc-yl30o1-9"]{content:"fjWSiv,"}/*!sc*/
# @font-face{font-weight:400;font-family:Filson Soft;src:url('https://assets.marmiton.org/assets/fonts/Filson_Soft/Regular/FilsonSoft-Regular.woff2') format('woff2');font-display:swap;}/*!sc*/
# @font-face{font-weight:700;font-family:Filson Soft;src:url('https://assets.marmiton.org/assets/fonts/Filson_Soft/Bold/FilsonSoft-Bold.woff2') format('woff2');font-display:swap;}/*!sc*/
# @font-face{font-weight:500;font-family:Filson Soft;src:url('https://assets.marmiton.org/assets/fonts/Filson_Soft/Medium/FilsonSoft-Medium.woff2') format('woff2');font-display:swap;}/*!sc*/
# @font-face{font-weight:400;font-family:Open Sans;src:url('https://assets.marmiton.org/assets/fonts/Open_Sans/Regular/Open-Sans.woff2') format('woff2');font-display:swap;}/*!sc*/
# @font-face{font-weight:600;font-family:Open Sans;src:url('https://assets.marmiton.org/assets/fonts/Open_Sans/SemiBold/Open-Sans-SemiBold.woff2') format('woff2');font-display:swap;}/*!sc*/
# @font-face{font-weight:700;font-family:Open Sans;src:url('https://assets.marmiton.org/assets/fonts/Open_Sans/Bold/Open-Sans-Bold.woff2') format('woff2');font-display:swap;}/*!sc*/
# data-styled.g375[id="sc-global-gdrWpY1"]{content:"sc-global-gdrWpY1,"}/*!sc*/
# html{-webkit-scroll-behavior:smooth;-moz-scroll-behavior:smooth;-ms-scroll-behavior:smooth;scroll-behavior:smooth;}/*!sc*/
# data-styled.g376[id="sc-global-kpcuqx1"]{content:"sc-global-kpcuqx1,"}/*!sc*/
# .ccNYDC{position:-webkit-sticky;position:sticky;top:0;z-index:200;margin-bottom:10px;}/*!sc*/
# data-styled.g565[id="MRTN__sc-1uwks53-0"]{content:"ccNYDC,"}/*!sc*/
# @font-face{font-family:swiper-icons;src:url('data:application/font-woff;charset=utf-8;base64, ...') format('woff');font-weight:400;font-style:normal;}/*!sc*/
# :root{--swiper-theme-color:#007aff;}/*!sc*/
# .swiper-container{margin-left:auto;margin-right:auto;position:relative;overflow:hidden;list-style:none;padding:0;z-index:1;}/*!sc*/
# .swiper-container-vertical>.swiper-wrapper{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .swiper-wrapper{position:relative;width:100%;height:100%;z-index:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-transition-property:-webkit-transform;-webkit-transition-property:transform;transition-property:transform;box-sizing:content-box;}/*!sc*/
# .swiper-container-android .swiper-slide,.swiper-wrapper{-webkit-transform:translate3d(0px,0,0);-ms-transform:translate3d(0px,0,0);transform:translate3d(0px,0,0);}/*!sc*/
# .swiper-container-multirow>.swiper-wrapper{-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .swiper-container-multirow-column>.swiper-wrapper{-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .swiper-container-free-mode>.swiper-wrapper{-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;margin:0 auto;}/*!sc*/
# .swiper-slide{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:100%;height:100%;position:relative;-webkit-transition-property:-webkit-transform;-webkit-transition-property:transform;transition-property:transform;}/*!sc*/
# .swiper-slide-invisible-blank{visibility:hidden;}/*!sc*/
# .swiper-container-autoheight,.swiper-container-autoheight .swiper-slide{height:auto;}/*!sc*/
# .swiper-container-autoheight .swiper-wrapper{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-transition-property:-webkit-transform,height;-webkit-transition-property:transform,height;transition-property:transform,height;}/*!sc*/
# .swiper-container-3d{-webkit-perspective:1200px;-moz-perspective:1200px;-ms-perspective:1200px;perspective:1200px;}/*!sc*/
# .swiper-container-3d .swiper-cube-shadow,.swiper-container-3d .swiper-slide,.swiper-container-3d .swiper-slide-shadow-bottom,.swiper-container-3d .swiper-slide-shadow-left,.swiper-container-3d .swiper-slide-shadow-right,.swiper-container-3d .swiper-slide-shadow-top,.swiper-container-3d .swiper-wrapper{-webkit-transform-style:preserve-3d;-ms-transform-style:preserve-3d;transform-style:preserve-3d;}/*!sc*/
# .swiper-container-3d .swiper-slide-shadow-bottom,.swiper-container-3d .swiper-slide-shadow-left,.swiper-container-3d .swiper-slide-shadow-right,.swiper-container-3d .swiper-slide-shadow-top{position:absolute;left:0;top:0;width:100%;height:100%;pointer-events:none;z-index:10;}/*!sc*/
# .swiper-container-3d .swiper-slide-shadow-left{background-image:linear-gradient(to left,rgba(0,0,0,.5),rgba(0,0,0,0));}/*!sc*/
# .swiper-container-3d .swiper-slide-shadow-right{background-image:linear-gradient(to right,rgba(0,0,0,.5),rgba(0,0,0,0));}/*!sc*/
# .swiper-container-3d .swiper-slide-shadow-top{background-image:linear-gradient(to top,rgba(0,0,0,.5),rgba(0,0,0,0));}/*!sc*/
# .swiper-container-3d .swiper-slide-shadow-bottom{background-image:linear-gradient(to bottom,rgba(0,0,0,.5),rgba(0,0,0,0));}/*!sc*/
# .swiper-container-css-mode>.swiper-wrapper{overflow:auto;-webkit-scrollbar-width:none;-moz-scrollbar-width:none;-ms-scrollbar-width:none;scrollbar-width:none;-ms-overflow-style:none;}/*!sc*/
# .swiper-container-css-mode>.swiper-wrapper::-webkit-scrollbar{display:none;}/*!sc*/
# .swiper-container-css-mode>.swiper-wrapper>.swiper-slide{-webkit-scroll-snap-align:start start;-moz-scroll-snap-align:start start;-ms-scroll-snap-align:start start;scroll-snap-align:start start;}/*!sc*/
# .swiper-container-horizontal.swiper-container-css-mode>.swiper-wrapper{-webkit-scroll-snap-type:x mandatory;-moz-scroll-snap-type:x mandatory;-ms-scroll-snap-type:x mandatory;scroll-snap-type:x mandatory;}/*!sc*/
# .swiper-container-vertical.swiper-container-css-mode>.swiper-wrapper{-webkit-scroll-snap-type:y mandatory;-moz-scroll-snap-type:y mandatory;-ms-scroll-snap-type:y mandatory;scroll-snap-type:y mandatory;}/*!sc*/
# :root{--swiper-navigation-size:44px;}/*!sc*/
# .swiper-button-next,.swiper-button-prev{position:absolute;top:50%;width:calc(var(--swiper-navigation-size)/ 44 * 27);height:var(--swiper-navigation-size);margin-top:calc(-1 * var(--swiper-navigation-size)/ 2);z-index:10;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;color:var(--swiper-navigation-color,var(--swiper-theme-color));}/*!sc*/
# .swiper-button-next.swiper-button-disabled,.swiper-button-prev.swiper-button-disabled{opacity:.35;cursor:auto;pointer-events:none;}/*!sc*/
# .swiper-button-next:after,.swiper-button-prev:after{font-family:swiper-icons;font-size:var(--swiper-navigation-size);text-transform:none!important;-webkit-letter-spacing:0;-moz-letter-spacing:0;-ms-letter-spacing:0;letter-spacing:0;text-transform:none;font-variant:initial;line-height:1;}/*!sc*/
# .swiper-button-prev,.swiper-container-rtl .swiper-button-next{left:10px;right:auto;}/*!sc*/
# .swiper-button-prev:after,.swiper-container-rtl .swiper-button-next:after{content:'prev';}/*!sc*/
# .swiper-button-next,.swiper-container-rtl .swiper-button-prev{right:10px;left:auto;}/*!sc*/
# .swiper-button-next:after,.swiper-container-rtl .swiper-button-prev:after{content:'next';}/*!sc*/
# .swiper-button-next.swiper-button-white,.swiper-button-prev.swiper-button-white{--swiper-navigation-color:#ffffff;}/*!sc*/
# .swiper-button-next.swiper-button-black,.swiper-button-prev.swiper-button-black{--swiper-navigation-color:#000000;}/*!sc*/
# .swiper-button-lock{display:none;}/*!sc*/
# .swiper-pagination{position:absolute;text-align:center;-webkit-transition:.3s opacity;transition:.3s opacity;-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);z-index:10;}/*!sc*/
# .swiper-pagination.swiper-pagination-hidden{opacity:0;}/*!sc*/
# .swiper-container-horizontal>.swiper-pagination-bullets,.swiper-pagination-custom,.swiper-pagination-fraction{bottom:10px;left:0;width:100%;}/*!sc*/
# .swiper-pagination-bullets-dynamic{overflow:hidden;font-size:0;}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet{-webkit-transform:scale(.33);-ms-transform:scale(.33);transform:scale(.33);position:relative;}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-main{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-prev{-webkit-transform:scale(.66);-ms-transform:scale(.66);transform:scale(.66);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-prev-prev{-webkit-transform:scale(.33);-ms-transform:scale(.33);transform:scale(.33);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-next{-webkit-transform:scale(.66);-ms-transform:scale(.66);transform:scale(.66);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-next-next{-webkit-transform:scale(.33);-ms-transform:scale(.33);transform:scale(.33);}/*!sc*/
# .swiper-pagination-bullet{width:8px;height:8px;display:inline-block;border-radius:100%;background:#000;opacity:.2;}/*!sc*/
# button.swiper-pagination-bullet{border:none;margin:0;padding:0;box-shadow:none;-webkit-appearance:none;-moz-appearance:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .swiper-pagination-clickable .swiper-pagination-bullet{cursor:pointer;}/*!sc*/
# .swiper-pagination-bullet-active{opacity:1;background:var(--swiper-pagination-color,var(--swiper-theme-color));}/*!sc*/
# .swiper-container-vertical>.swiper-pagination-bullets{right:10px;top:50%;-webkit-transform:translate3d(0px,-50%,0);-ms-transform:translate3d(0px,-50%,0);transform:translate3d(0px,-50%,0);}/*!sc*/
# ...
# </svg>
# </a>
# <a class="_blank social-icon-holder" href="https://www.instagram.com/marmiton_org/">
# <svg class="svg-icon" viewbox="0 0 35 35">
# <path d="M1.333 16.667c0-8.1 6.567-14.667 14.667-14.667s14.667 6.567 14.667 14.667c0 8.1-6.567 14.667-14.667 14.667s-14.667-6.567-14.667-14.667v0zM16.001 8.844c-2.125 0-2.392 0.009-3.225 0.048-0.833 0.037-1.401 0.169-1.899 0.363-0.515 0.2-0.952 0.468-1.387 0.903s-0.701 0.871-0.903 1.385c-0.193 0.497-0.325 1.067-0.363 1.899-0.037 0.835-0.048 1.101-0.048 3.225s0.009 2.391 0.048 3.225c0.037 0.832 0.169 1.4 0.363 1.897 0.2 0.515 0.468 0.952 0.903 1.387s0.871 0.703 1.385 0.903c0.497 0.193 1.067 0.325 1.899 0.363 0.835 0.039 1.101 0.048 3.225 0.048s2.391-0.009 3.224-0.048c0.833-0.037 1.403-0.169 1.9-0.363 0.515-0.2 0.951-0.468 1.385-0.903s0.701-0.872 0.903-1.385c0.192-0.499 0.324-1.067 0.363-1.899 0.037-0.835 0.048-1.101 0.048-3.225s-0.011-2.391-0.048-3.225c-0.039-0.833-0.171-1.401-0.363-1.899-0.201-0.515-0.468-0.951-0.903-1.385-0.436-0.435-0.871-0.703-1.385-0.903-0.499-0.193-1.068-0.325-1.9-0.363-0.835-0.039-1.1-0.048-3.225-0.048h0.003zM12.84 10.296c-0.763 0.035-1.177 0.163-1.452 0.269-0.367 0.143-0.627 0.312-0.9 0.585s-0.444 0.535-0.585 0.9c-0.107 0.276-0.235 0.689-0.269 1.452-0.039 0.824-0.045 1.072-0.045 3.16 0 2.089 0.007 2.336 0.045 3.161 0.035 0.763 0.163 1.176 0.269 1.452 0.143 0.365 0.312 0.625 0.585 0.899s0.533 0.443 0.9 0.585c0.275 0.108 0.689 0.235 1.452 0.269 0.824 0.037 1.072 0.045 3.161 0.045 2.087 0 2.336-0.008 3.16-0.045 0.763-0.035 1.177-0.161 1.452-0.269 0.367-0.143 0.625-0.312 0.899-0.585 0.275-0.273 0.444-0.533 0.585-0.899 0.108-0.275 0.236-0.688 0.271-1.452 0.037-0.824 0.045-1.072 0.045-3.16 0-2.087-0.008-2.335-0.045-3.159-0.035-0.764-0.163-1.177-0.271-1.452-0.141-0.367-0.311-0.627-0.585-0.9-0.273-0.273-0.532-0.443-0.899-0.585-0.275-0.108-0.689-0.235-1.452-0.269-0.824-0.037-1.073-0.045-3.16-0.045h-0.703v-0.001c-1.457 0.001-1.737 0.011-2.459 0.044zM19.237 12.491c0-0.519 0.421-0.939 0.94-0.939 0.516 0 0.937 0.42 0.937 0.939s-0.421 0.939-0.937 0.939c-0.519 0-0.94-0.42-0.94-0.939zM11.983 16.666c0-2.217 1.799-4.016 4.019-4.016 2.219 0 4.016 1.799 4.016 4.016 0 2.22-1.797 4.017-4.016 4.017-2.22 0-4.019-1.797-4.019-4.017zM13.393 16.666c0 1.44 1.168 2.608 2.608 2.608s2.607-1.168 2.607-2.608c0-1.44-1.167-2.605-2.607-2.605s-2.608 1.165-2.608 2.605z"></path>
# </svg>
# </a>
# <a class="social-icon-holder" href="https://www.youtube.com/user/marmitonofficiel">
# <svg class="svg-icon" viewbox="0 0 35 35">
# <path d="M1.333 16.667c0-8.1 6.567-14.667 14.667-14.667s14.667 6.567 14.667 14.667c0 8.1-6.567 14.667-14.667 14.667s-14.667-6.567-14.667-14.667zM23.665 13.715c0 0-0.152-1.101-0.621-1.587-0.595-0.637-1.261-0.64-1.568-0.677-2.189-0.161-5.472-0.161-5.472-0.161h-0.008c0 0-3.283 0-5.472 0.161-0.307 0.037-0.973 0.040-1.568 0.677-0.469 0.485-0.621 1.587-0.621 1.587s-0.157 1.293-0.157 2.587v1.213c0 1.295 0.157 2.588 0.157 2.588s0.152 1.101 0.621 1.587c0.595 0.637 1.377 0.617 1.725 0.683 1.251 0.124 5.319 0.161 5.319 0.161s3.287-0.005 5.476-0.167c0.307-0.037 0.973-0.040 1.568-0.677 0.469-0.485 0.621-1.587 0.621-1.587s0.157-1.293 0.157-2.588v-1.213c0-1.293-0.157-2.587-0.157-2.587zM14.385 18.985v-4.492l4.227 2.253z"></path>
# </svg>
# </a>
# <a class="_blank social-icon-holder" href="https://assistant.google.com/services/invoke/uid/00000058f69ad4c0">
# <svg class="svg-icon" viewbox="0 0 35 35">
# <path d="M15.95 0.767c-8.8 0-15.85 7.050-15.85 15.85s7.15 15.95 15.95 15.95 15.85-7.15 15.85-15.95-7.15-15.85-15.95-15.85zM21.6 14.217c1.4 0 2.6 1.2 2.6 2.6s-1.2 2.6-2.6 2.6c-1.4 0-2.6-1.2-2.6-2.6s1.050-2.6 2.6-2.6zM11.8 19.417c-3.6 0-6.4-2.95-6.4-6.4 0-3.6 2.95-6.4 6.4-6.4s6.5 2.8 6.5 6.4-2.9 6.4-6.5 6.4zM21.6 26.717c-1.75 0-3.15-1.4-3.15-3.15s1.4-3.15 3.15-3.15c1.75 0 3.15 1.4 3.15 3.15 0 1.7-1.45 3.15-3.15 3.15zM25.25 14.967c-0.75 0-1.3-0.55-1.3-1.3s0.55-1.3 1.3-1.3 1.3 0.55 1.3 1.3c0.050 0.65-0.6 1.3-1.3 1.3z"></path>
# </svg>
# </a>
# </p>
# <div class="padded-content">
# <div class="mrtn-autopromo-ctnr">
# <a class="_blank mrtn-autopromo" href="http://m.onelink.me/b78587d4">
# <span class="img-iphone">
# <img alt="Iphone" height="102" loading="lazy" src="https://static.afcdn.com/relmrtn/Front/Component/footerLight/assets/iPhone.png" style=" aspect-ratio: 57/102;" width="57"/> </span>
# <p class="title-4">Retrouvez Marmiton où que vous soyez en téléchargeant l'application</p>
# </a>
# </div>
# </div>
# </div>
# <div class="endFooter-desktop">
# <div class="links">
# <div class="i-b">
# <div class="item switchState">
# <h3>Recettes<span class="float-right"><i class="icon icon-icon_plus"></i></span></h3>
# <ul class="toSwitch closed">
# <li><a href="/recettes/index/ingredient">Index des recettes</a></li>
# <li><a href="/dossier-noel/">Noël</a></li>
# <li><a href="/paques/nos-recettes-pour-paques-s4000253.html">Pâques</a></li>
# <li><a href="/recettes/selection_chandeleur.aspx">Chandeleur</a></li>
# </ul>
# </div>
# </div>
# <div class="i-b">
# <div class="item switchState">
# <h3>Recette par thématique<span class="float-right"><i class="icon icon-icon_plus"></i></span></h3>
# <ul class="toSwitch closed column-4">
# <li><a href="https://www.marmiton.org/recettes/selection_automne.aspx">Automne</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_hiver.aspx">Hiver</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_printemps.aspx">Printemps</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_ete.aspx">Eté</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_afrique.aspx">Afrique</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_alsace.aspx">Alsace</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_asie.aspx">Asie</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_sud-ouest.aspx">Sud-Ouest</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_cuisine_corse.aspx">Corse</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_cuisine_espagnole.aspx">Espagne</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_cuisine_libanaise.aspx">Liban</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_indienne.aspx">Inde</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_italienne.aspx">Italie</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_recettes_bretonnes.aspx">Bretagne</a></li>
# <li><a href="https://www.marmiton.org/recettes/album1324399/cuisine-francaise-65-recettes-traditionnelles-0.html#p1">Cuisine Française</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_citadin.aspx">Rapide Et Facile</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_debutant.aspx">Je Débute</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_poisson.aspx">Poissons</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_salade.aspx">Salades</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_soupe.aspx">Soupes</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_cocktail_et_boisson.aspx">Boissons</a></li>
# <li><a href="https://www.1001cocktails.com/">Cocktails</a></li>
# <li><a href="https://www.marmiton.org/recettes/recherche.aspx?aqt=b%C3%A9b%C3%A9">Bébés</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_enfants.aspx">Cuisine Pour Enfants</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_etudiant.aspx">Moins Cher</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_mincealors.aspx">Mince Alors !</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_petit_dejeuner.aspx">Petit Déjeuner</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/categorie/gateau/">Gâteau</a></li>
# <li><a href="https://www.marmiton.org/recettes/selection_vegetarien.aspx">Végétarien</a></li>
# <li><a href="https://www.marmiton.org/cuisine-rapide/l-aperitif-tp124496.html">Apéro dînatoire</a></li>
# <li><a href="https://www.marmiton.org/recettes/recette_pate-a-crepes_12372.aspx">Pâte à crêpes</a></li>
# <li><a href="https://www.marmiton.org/recettes/recette_pate-sablee_14540.aspx">Pâte sablée</a></li>
# </ul>
# </div>
# </div>
# <div class="i-b">
# <div class="item switchState">
# <h3>Forum<span class="float-right"><i class="icon icon-icon_plus"></i></span></h3>
# <ul class="toSwitch closed">
# <li><a href="https://www.marmiton.org/forum/">Questions / Réponses</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="foot-content">
# <h3>Index des ingrédients</h3>
# <ul class="ingredient-index">
# <li><a href="https://www.marmiton.org/recettes/index/ingredient">A</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/b">B</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/c">C</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/d">D</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/e">E</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/f">F</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/g">G</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/h">H</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/i">I</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/j">J</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/k">K</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/l">L</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/m">M</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/n">N</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/o">O</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/p">P</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/q">Q</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/r">R</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/s">S</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/t">T</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/v">U</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/w">W</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/x">X</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/y">Y</a></li>
# <li><a href="https://www.marmiton.org/recettes/index/ingredient/z">Z</a></li>
# </ul>
# </div>
# <div class="foot-content">
# <p class="text-center">Concocté avec ♥ par Marmiton</p>
# <div class="foot-content padded-content">
# <div class="last-links">
# <p>Tous droits réservés Marmiton.org - 1999-2023</p>
# <p>
# <a href="javascript:showCmpPreferencesPopup()">Paramétrer les cookies</a> ●
#                         <a class="_blank" href="https://marmiton.welcomekit.co/">Recrutement</a> ●
#                         <a href="https://www.marmiton.org/sp/aide/mentions-legales.html">Mentions légales</a> ●
#                         <a href="https://www.marmiton.org/sp/aide/conditions-generales-utilisation.html">Conditions Générales d'Utilisation</a> ●
# 						<a href="https://www.marmiton.org/sp/legal/conditions_generales_abonnement.html">Conditions Générales d'Abonnement</a> ●
#                         <a href="/contact">Contact</a> ●
#                         <a href="https://www.marmiton.org/aide/faq-foire-aux-questions-s4005514.html">FAQ</a> ●
#                         <a href="https://www.marmiton.org/sp/aide/politque-de-protection-des-donnees-personnelles.html">Politique de protection des données personnelles</a> ●
#                         <a href="https://www.marmiton.org/sp/aide/faq-protection-des-donnees-personnelles.html#NotDisplayCmp">Foire aux questions - Vos choix concernant l'utilisation de cookies</a>
# </p>
# <p>Pour des milliers de cocktails : <a href="http://www.1001cocktails.com">1001cocktails.com</a></p>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div></div></div></div></div><script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{"homePageData":{"homeBlocksData":[{"type":"dailyRecipeBlock","component":"slider","position":0,"isVisible":true,"items":[{"id":72593,"publication_date":"2023-07-07T00:00:00+02:00","title":"La Vraie Moussaka Grecque","link":"https://www.marmiton.org/recettes/recette_la-vraie-moussaka-grecque_72593.aspx","rating":4.9,"nbReviews":956,"sponsored":false,"hasVideo":true,"disType":"Plat principal","isVegetarian":false,"isFavorite":"","tag":"","brand":{"id":null,"name":null},"picture":{"id":133014,"url":"https://assets.afcdn.com/recipe/20220623/133014_origin.jpg","credits":"lisegagne/ E+/ getty images"},"publicationDate":"2023-07-07T00:00:00+02:00"},{"id":13587,"publication_date":"2023-07-06T00:00:00+02:00","title":"Curry de lotte au lait de coco","link":"https://www.marmiton.org/recettes/recette_curry-de-lotte-au-lait-de-coco_13587.aspx","rating":4.8,"nbReviews":176,"sponsored":false,"hasVideo":true,"disType":"Plat principal","isVegetarian":false,"isFavorite":"","tag":"","brand":{"id":null,"name":null},"picture":{"id":77484,"url":"https://assets.afcdn.com/recipe/20180209/77484_origin.jpg","credits":"Shutterstock"},"publicationDate":"2023-07-06T00:00:00+02:00"},{"id":344471,"publication_date":"2023-07-05T00:00:00+02:00","title":"Tarte tourbillon chèvre courgette miel","link":"https://www.marmiton.org/recettes/recette_tarte-tourbillon-chevre-courgette-miel_344471.aspx","rating":4.7,"nbReviews":25,"sponsored":false,"hasVideo":true,"disType":"Entrée","isVegetarian":true,"isFavorite":"","tag":"","brand":{"id":null,"name":null},"picture":{"id":32189,"url":"https://assets.afcdn.com/recipe/20160527/32189_origin.jpg","credits":"marmiton"},"publicationDate":"2023-07-05T00:00:00+02:00"}]},{"type":"searchBarBlock","component":"searchBarComponent","isVisible":true,"position":1,"items":[]},{"type":"lastContentsBlock","component":"slider","isVisible":true,"position":2,"cardType":"miscOverlay","itemType":"misc","seeMoreUrl":"https://www.marmiton.org/cuisine-rapide/actus-food-tp123982.html","title":"Consultez nos dernières actus","items":[{"id":"4066907","title":"Conservation des aliments : voici la température idéale pour régler votre frigo !","contentTypeId":49,"subTitle":" Cuisine du quotidien","subTitleUrl":"/cuisine-du-quotidien-sc26.html","iconUrl":"","url":"https://www.marmiton.org/gestes-et-tours-de-mains/conservation-des-aliments-voici-la-temperature-ideale-pour-regler-votre-frigo-s4066907.html","picture":{"id":null,"url":"https://assets.afcdn.com/story/acc9_4066907/acc157213501_w1257h1257c1cx515cy671cxt0cyt0cxb2148cyb1416.jpg","credits":null},"isOPS":false,"section":{"id":26,"rubrique":" Cuisine du quotidien","titreHtml":"Cuisine du quotidien","metaDesc":"Cuisine du quotidien","homerubriqueurl":"/cuisine-du-quotidien-sc26.html"},"modificationDate":"2023-07-07T08:00:00+02:00","authorName":"Pénélope Fajon","contentType":"article"},{"id":"4066964","title":"Voici l'ustensile insoupçonné pour préparer une mayonnaise inratable en moins de 2 minutes","contentTypeId":49,"subTitle":" Cuisine du quotidien","subTitleUrl":"/cuisine-du-quotidien-sc26.html","iconUrl":"","url":"https://www.marmiton.org/trucs-et-astuces/voici-l-ustensile-insoupconne-pour-preparer-une-mayonnaise-inratable-en-moins-de-2-minutes-s4066964.html","picture":{"id":null,"url":"https://assets.afcdn.com/story/acc9_4066964/acc1864892542_w1257h1257c1cx2289cy1601cxt0cyt0cxb4577cyb3202.jpg","credits":null},"isOPS":false,"section":{"id":26,"rubrique":" Cuisine du quotidien","titreHtml":"Cuisine du quotidien","metaDesc":"Cuisine du quotidien","homerubriqueurl":"/cuisine-du-quotidien-sc26.html"},"modificationDate":"2023-07-07T07:00:00+02:00","authorName":"Orane Scherschel","contentType":"article"},{"id":"4066896","title":"Œufs : cette astuce de grand-mère que l’on utilise tous pour les cuire ne sert à rien !","contentTypeId":49,"subTitle":" Cuisine du quotidien","subTitleUrl":"/cuisine-du ...

# %%
lien_class_specifique = soup.find_all("a", class_="MRTN__sc-gkm9mr-3 jXEnlf")
lien_class_specifique
# Out:
# [<a class="MRTN__sc-gkm9mr-3 jXEnlf" href="https://www.marmiton.org/dossier-recettes-barbecue" rel="">Spécial barbecue</a>,
#  <a class="MRTN__sc-gkm9mr-3 jXEnlf" href="https://www.marmiton.org/dossier-recettes-ete" rel="">Cuisine d'été</a>,
#  <a class="MRTN__sc-gkm9mr-3 jXEnlf" href="/cuisine-rapide/actus-food-tp123982.html" rel="">Actus</a>,
#  <a class="MRTN__sc-gkm9mr-3 jXEnlf" href="/mieux-cuisiner/mieux-manger-tp125264.html" rel="">Mieux manger</a>]
